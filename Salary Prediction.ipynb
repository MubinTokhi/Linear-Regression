# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as smf
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data Loading and Preproccesing

# %%
df= pd.read_csv(r"C:\Users\mobin\DATASIENCE\ML Assignments\STATISTICS\Linear Regression\Salary_Data.csv")

# %%
df.head()
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
df.shape
# Out:
# (30, 2)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   YearsExperience  30 non-null     float64
#  1   Salary           30 non-null     float64
# dtypes: float64(2)
# memory usage: 612.0 bytes

# %%
df.isnull().sum()
# Out:
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.corr()
# Out:
#                  YearsExperience    Salary
# YearsExperience         1.000000  0.978242
# Salary                  0.978242  1.000000

# %% [markdown]
# ## DATA VISUALIZATION

# %%
sns.boxplot(df['YearsExperience'])
# Out:
# <Axes: >

# %%
sns.distplot(df['YearsExperience'])
# Out:
# C:\Users\mobin\AppData\Local\Temp\ipykernel_20084\3871720387.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['YearsExperience'])
# <Axes: xlabel='YearsExperience', ylabel='Density'>

# %%
sns.distplot(df['Salary'])
# Out:
# C:\Users\mobin\AppData\Local\Temp\ipykernel_20084\3249851952.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Salary'])
# <Axes: xlabel='Salary', ylabel='Density'>

# %%
sns.regplot(data = df, x = df['YearsExperience'] , y = df['Salary'])
# Out:
# <Axes: xlabel='YearsExperience', ylabel='Salary'>

# %% [markdown]
# ## CREATING A REGRESSION MODEL AND PREDICTING BY USING OLS ALGO

# %%
model = smf.ols('Salary~YearsExperience', data=df).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                 Salary   R-squared:                       0.957
# Model:                            OLS   Adj. R-squared:                  0.955
# Method:                 Least Squares   F-statistic:                     622.5
# Date:                Wed, 20 Mar 2024   Prob (F-statistic):           1.14e-20
# Time:                        22:20:23   Log-Likelihood:                -301.44
# No. Observations:                  30   AIC:                             606.9
# Df Residuals:                      28   BIC:                             609.7
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# ...

# %%
x = df['YearsExperience']
y = df['Salary']

plt.scatter(x,y)

b0 = 2.579e+04
b1 = 9449.9623

y_hat = b0 + b1 * x

plt.plot(x,y_hat)

plt.xlabel('Year Of Exp')
plt.ylabel('Salary')
plt.show()

# %%
pred_y = model.predict(df['YearsExperience'])
pred_y
# Out:
# 0      36187.158752
# 1      38077.151217
# 2      39967.143681
# 3      44692.124842
# 4      46582.117306
# 5      53197.090931
# 6      54142.087163
# 7      56032.079627
# 8      56032.079627
# 9      60757.060788
# 10     62647.053252
# 11     63592.049484
# 12     63592.049484
# 13     64537.045717
# 14     68317.030645
# 15     72097.015574
# 16     73987.008038
# 17     75877.000502
# 18     81546.977895
# 19     82491.974127
# 20     90051.943985
# 21     92886.932681
# 22    100446.902538
# 23    103281.891235
# 24    108006.872395
# 25    110841.861092
# 26    115566.842252
# 27    116511.838485
# 28    123126.812110
# 29    125016.804574
# dtype: float64

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_percentage_error

# %%
MSE = mean_squared_error(df['Salary'] , pred_y)
MSE
# Out:
# 31270951.72228097

# %%
import numpy as np

# %%
np.sqrt(MSE)
# Out:
# 5592.043608760662
